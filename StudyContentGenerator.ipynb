# %%
! pip install -q -U google-generativeai
! pip install --upgrade transformers
! pip install langchain
! pip install langchain-huggingface

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.output_parsers import StructuredOutputParser
from langchain.output_parsers import ResponseSchema
import random
import string
import google.generativeai as genai
import os
import copy
import json

# %%
os.environ["API_KEY"] = "AIzaSyDHPHb5WhqTfbcrcRyqtpogbbAHy3AK3JQ"
genai.configure(api_key=os.environ["API_KEY"])

# %%
devotional_template_string = """You are tasked with creating christian-biblical \
devotionals, given a theme description and a period of time. Your task is to \
create the devotional for the current day; then you'll also recive a list
of the previous devotionals in the range of time and a general description of each. The theme description \
will tell you whats the general theme to talk about the whole period of time.

Theme description: ```{theme_description}```
Period of time: ```{period_of_time}```
Previous devotionals: ```{prev_study_content}```

In case the user is trying to update or modify the \
current devotional, the following fields will have some instructions \
and what it should be modified:
User instructions: ```{user_instructions}```
Devotional to Modify: ```{content_to_modify}```

Based on this information, create the question and its answers by selecting a\
single theme from the theme description. Please return the response in the\
specified JSON format only.

{format_instructions}

"""
activity_template_string = """You are tasked with creating ```{question_type}``` questions for \
dynamic daily devotion activities focused on biblical studies. Using the provided theme description, \
create a question related to this Christian-biblical theme based on the specified question type.

Theme description: ```{theme_description}```
Question type: ```{question_type}```
Focus Ages: ```{age_range}```

Here are the previous questions to avoid repeating the same things:
Previous questions: [```{prev_activities}```]

Based on this information, create the question and its answers by selecting a\
single theme from the theme description. Please return the response in the\
specified JSON format only.

{format_instructions}
"""

# %%
devotional_output_schema = {
    "title"       : ResponseSchema(name="title_text", description="String title of the devotional"),
    "description" : ResponseSchema(name="description_text", description="String description of the devotional"),
    "content"     : ResponseSchema(name="content_text", description="String content of the devotional"),
}
output_schemas = {
    "multiple_choice" : {
        "question"  : ResponseSchema(name="question_text", description="String of the question"),
        "answer"    : ResponseSchema(name="answer_text", description="String of the correct answer"),
        "options"   : ResponseSchema(name="options_list", description="Array of incorrect answers. 5 at list")
    },
    "open_ended_question" : {
        "question"  : ResponseSchema(name="question_text", description="String of the question"),
        "hint"      : ResponseSchema(name="hint_text", description="String of hint answer"),
        "answer"    : ResponseSchema(name="answer_text", description="String of the actual expected answer"),
    },
    "word_order" : {
        "question"        : ResponseSchema(name="question_text", description="String of the question"),
        "unordered_word"  : ResponseSchema(name="unordered_word_text", description="String of the unordered word. All characters mixed up; same amount of characters as the original word."),
        "ordered_word"    : ResponseSchema(name="ordered_word_text", description="String of the correct ordered word"),
    },
    "sentence_order" : {
        "question"            : ResponseSchema(name="question_text", description="String of the question"),
        "unordered_sentence"  : ResponseSchema(name="unordered_sentence_text", description="String of the unordered sentence. All words mixed up."),
        "ordered_sentence"    : ResponseSchema(name="ordered_sentence_text", description="String of the ordered sentence")
    },
    "matching" : {
        "question"      : ResponseSchema(name="question_text", description="String of the question"),
        "list_options"  : ResponseSchema(name="list_options", description="Array of 5 options"),
        "list_matches"  : ResponseSchema(name="list_matches", description="Array of 5 matches in order to the options"),
    },
    "fill_in_the_blanks" : {
        "question"      : ResponseSchema(name="question_text", description="String of the sentence with blanks to fill"),
        "blanks_values" : ResponseSchema(name="list_blank_values", description="Array of the correct values to fill the blanks with.")
    },
    "true_or_false" : {
        "question"      : ResponseSchema(name="question_text", description="String of the true or false question"),
        "answer"        : ResponseSchema(name="answer_bool", description="Bool value indicating if the sentence is true or false"),
    }
}

# %%
def generate_random_id(length):
  characters = string.ascii_letters + string.digits
  return ''.join(random.choice(characters) for _ in range(length))

# %%
class ActivityGenerator:
  def __init__(self, theme_description, age_range, prompt_template, output_schemas, model):
    self.theme_description      = theme_description
    self.age_range              = age_range
    self.prompt_template        = prompt_template
    self.prompt                 = ChatPromptTemplate.from_template(template=prompt_template)
    self.output_schemas         = copy.copy(output_schemas)
    self.output_parsers         = {}
    self.model                  = model
    self.generated_activities   = [] # This holds the generated activities
    self.process_schemas()

  def process_schemas(self):
    for k in self.output_schemas.keys():
      self.output_schemas[k]  = list(self.output_schemas[k].values())
      self.output_parsers[k]  = StructuredOutputParser.from_response_schemas(self.output_schemas[k])
      self.output_schemas[k]  = self.output_parsers[k].get_format_instructions()
  def generate_message(self):
    question_type   = random.choice(list(self.output_schemas.keys()))
    prev_activities = [act["question_text"] for act in self.generated_activities]
    message         = self.prompt.format_messages(
        question_type       = question_type,
        theme_description   = self.theme_description,
        age_range           = self.age_range,
        prev_activities     = prev_activities,
        format_instructions = self.output_schemas[question_type]
    )
    return message[0].content, question_type

  def generate_message_by_type(self, activity_type):
    prev_activities = [act["question_text"] for act in self.generated_activities]
    message         = self.prompt.format_messages(
        question_type       = activity_type,
        theme_description   = self.theme_description,
        age_range           = self.age_range,
        prev_activities     = prev_activities,
        format_instructions = self.output_schemas[activity_type]
    )
    return message[0].content, activity_type


  def generate_activity(self, sms, question_type):
    response          = self.model.generate_content(sms)
    response_as_dict  = self.output_parsers[question_type].parse(response.text)
    response_as_dict["id_activity"] = generate_random_id(20)
    response_as_dict["question_type"] = question_type
    return response_as_dict

  def generate_activities(self, iterations):
    for it in range(iterations):
      sms, question_type  = self.generate_message()
      act                 = self.generate_activity(sms, question_type)
      self.generated_activities.append(act)
  def generate_activity_by_type(self, activity_type):
    sms, activity_type  = self.generate_message_by_type(activity_type)
    act                 = self.generate_activity(sms, activity_type)
    return act

# %%
class StudyContentGenerator:
  def __init__(self, theme_description, period_of_time, prompt_template, output_schema, model):
    self.theme_description        = theme_description
    self.period_of_time           = period_of_time
    self.prompt_template          = prompt_template
    self.prompt                   = ChatPromptTemplate.from_template(template=prompt_template)
    self.output_parser            = None
    self.output_schema            = output_schema
    self.model                    = model
    self.generated_study_content  = [] # holds the generated study
    self.process_schema()

  def process_schema(self):
    self.output_schema            = list(self.output_schema.values())
    self.output_parser            = StructuredOutputParser.from_response_schemas(self.output_schema)
    self.output_schema            = self.output_parser.get_format_instructions()

  def generate_message(self, user_instructions="", content_to_modify=""):
    prev_study_content  = [
        {"title_text": dev["title_text"], "description_text": dev["description_text"]} for dev in self.generated_study_content
    ]
    message = self.prompt.format_messages(
      theme_description   = self.theme_description,
      period_of_time      = self.period_of_time,
      prev_study_content  = prev_study_content,
      format_instructions = self.output_schema,
      user_instructions   = user_instructions,
      content_to_modify   = content_to_modify
    )
    return message[0].content
  def generate_study_content(self, sms):
    response          = self.model.generate_content(sms)
    response_as_dict  = self.output_parser.parse(response.text)
    response_as_dict["id_study_content"] = generate_random_id(20)
    return response_as_dict
  def generate_study_contents(self, iterations, user_instructions="", content_to_modify=""):
    for it in range(iterations):
      sms = self.generate_message(user_instructions, content_to_modify)
      study_content = self.generate_study_content(sms)
      self.generated_study_content.append(study_content)

# %%
# TODO add question type and ids
# TODO add delete or refresh question and study content

# %%
class ModuleGenerator:
  def __init__(self, theme_description, period_of_time, age_range, std_content_template, std_content_schema, act_template, act_schema, model):
    self.theme_description        = theme_description
    self.period_of_time           = period_of_time
    self.age_range                = age_range
    self.std_content_schema       = std_content_schema
    self.std_content_template     = std_content_template
    self.act_template             = act_template
    self.act_schema               = act_schema
    self.generated_content        = {}
    self.model                    = model

  def generate_content(self, std_iterations, acts_iterations):
    study_content_generator  = StudyContentGenerator(
        theme_description = theme_description,
        period_of_time    = period_of_time,
        prompt_template   = self.std_content_template,
        output_schema     = self.std_content_schema,
        model             = self.model
    )
    study_content_generator.generate_study_contents(std_iterations)
    self.generated_content["study_contents"]  = study_content_generator.generated_study_content
    for stdc in self.generated_content["study_contents"]:
      activity_generator  = ActivityGenerator(
          theme_description = stdc["content_text"],
          age_range         = self.age_range,
          prompt_template   = self.act_template,
          output_schemas    = self.act_schema,
          model             = self.model
      )
      activity_generator.generate_activities(acts_iterations)
      stdc["activities"]  = activity_generator.generated_activities
    return self.generated_content


  def load(self, generated_content):
    self.generated_content  = generated_content
  def regenerate_content(self, id, acts_iterations, user_instructions=""):
    study_content_generator = StudyContentGenerator(
        theme_description = self.theme_description,
        period_of_time    = self.period_of_time,
        prompt_template   = self.std_content_template,
        output_schema     = self.std_content_schema,
        model             = self.model
    )
    idx_it  = 0
    found   = False
    for i in range(len(self.generated_content["study_contents"])):
      if self.generated_content["study_contents"][i]["id_study_content"] == id:
        idx_it  = i
        found   = True
        break
    if found == False:
      print("Error")
      return {"status": "not found"}

    study_content_generator.generated_study_content =  self.generated_content["study_contents"][:idx_it]
    current_content = self.generated_content["study_contents"][idx_it]["content_text"]
    study_content_generator.generate_study_contents(1, user_instructions, current_content)
    self.generated_content["study_contents"][idx_it]  = study_content_generator.generated_study_content[-1]
    self.generated_content["study_contents"][idx_it]["id_study_content"] = id

    activity_generator = ActivityGenerator(
      theme_description = self.generated_content["study_contents"][idx_it]["content_text"],
      age_range         = self.age_range,
      prompt_template   = self.act_template,
      output_schemas    = self.act_schema,
      model             = self.model
    )
    activity_generator.generate_activities(acts_iterations)
    self.generated_content["study_contents"][idx_it]["activities"] = activity_generator.generated_activities
    return self.generated_content

  def regenerate_activity(self, id, act_type):
    for i, std_content_it in enumerate(self.generated_content["study_contents"]):
      for j, act_it in enumerate(std_content_it["activities"]):
        if act_it["id_activity"] == id:
          activity_generator = ActivityGenerator(
              theme_description   = std_content_it["content_text"],
              age_range           = self.age_range,
              prompt_template     = self.act_template,
              output_schemas      = self.act_schema,
              model               = self.model
          )
          activity_generator.generated_activities = std_content_it["activities"]
          new_act = activity_generator.generate_activity_by_type(act_type)
          self.generated_content["study_contents"][i]["activities"][j] = new_act
          self.generated_content["study_contents"][i]["activities"][j]["id_activity"] = id
          return self.generated_content
    return None

  def add_more_activities(self, id, n_activities):
    for i, std_content_it in enumerate(self.generated_content["study_contents"]):
      if std_content_it["id_study_content"] == id:
        activity_generator = ActivityGenerator(
            theme_description     = std_content_it["content_text"],
            age_range             = self.age_range,
            prompt_template       = self.act_template,
            output_schemas        = self.act_schema,
            model                 = self.model
        )
        activity_generator.generated_activities = std_content_it["activities"]
        activity_generator.generate_activities(n_activities)
        self.generated_content["study_contents"][i]["activities"] = activity_generator.generated_activities

# %%
theme_description = "The Peace of God in the Midst of Chaos. Reflect on how God's peace can guard our hearts and minds even during the tumult of war. Philippians 4:6-7 encourages us not to be anxious but to bring our requests to God, and His peace will transcend understanding. Meditate on Isaiah 26:3, which promises perfect peace to those whose minds are steadfast."
period_of_time    = "one week"
age_range = "Kids between 9 and 12"
model = genai.GenerativeModel('gemini-1.5-flash')

module_generator  = ModuleGenerator(
    theme_description   = theme_description,
    period_of_time      = period_of_time,
    age_range           = age_range,
    std_content_template=devotional_template_string,
    std_content_schema  =devotional_output_schema,
    act_template        =activity_template_string,
    act_schema          =output_schemas,
    model               =model
)

# %%
generated_content = module_generator.generate_content(3, 2)

# %%
print(json.dumps(generated_content, indent=4))
# Out:
# {
#     "study_contents": [
#         {
#             "title_text": "Finding Peace in a World of Conflict",
#             "description_text": "In the midst of turmoil and uncertainty, the promise of God's peace remains steadfast. Today's devotional explores how we can find that peace amidst the chaos.",
#             "content_text": "The world can feel like a chaotic and unpredictable place, especially when we are surrounded by conflict and unrest. The news is often filled with stories of war, violence, and suffering, and it can be easy to feel overwhelmed and anxious. But even in the midst of this turmoil, God promises us His peace.  \n\nPhilippians 4:6-7 reminds us, \"Do not be anxious about anything, but in every situation, by prayer and petition, with thanksgiving, present your requests to God. And the peace of God, which transcends all understanding, will guard your hearts and your minds in Christ Jesus.\" \n\nThis peace is not simply the absence of trouble; it is a deep, abiding peace that comes from knowing that God is in control. It is a peace that surpasses our understanding, a peace that is present even in the midst of storm.  \n\nHow can we find this peace? The passage tells us to bring our requests to God in prayer. When we acknowledge our fears and anxieties and surrender them to God, we open ourselves up to His peace. We also find peace by focusing on gratitude. When we focus on the good things in our lives, even in the midst of difficult circumstances, we cultivate a sense of peace and contentment.\n\nRemember, you are not alone. God is with you, and His peace is available to you, no matter what you are facing. Take time today to seek His peace through prayer, gratitude, and trusting in His goodness.",
#             "id_study_content": "mBZ1hWMsEsG9nNGI7swy",
#             "activities": [
#                 {
#                     "question_text": "How can focusing on the good things in life, even when things are tough, help us find peace?",
#                     "hint_text": "Think about times when something good happened even though you were going through a difficult time. How did that make you feel?",
#                     "answer_text": "Focusing on the good things reminds us that God is still working in our lives, even when we don't see it. It helps us to be grateful for what we have, which can bring us peace and contentment, even in the midst of challenges.",
#                     "id_activity": "8z6HuWm5RuJ51sLB4MVM",
#                     "question_type": "open_ended_question"
#                 },
#                 {
#                     "question_text": "What does the Bible say we can do to find peace even when the world feels chaotic?",
#                     "list_options": [
#                         "Sing loud songs",
#                         "Pray to God and tell Him our worries",
#                         "Read a book",
#                         "Take a nap",
#                         "Watch TV"
#                     ],
#                     "list_matches": [
#                         "Incorrect",
#                         "Correct",
#                         "Incorrect",
#                         "Incorrect",
#                         "Incorrect"
#                     ],
#                     "id_activity": "8eYOEr7SZx6L5TGlHvoF",
#                     "question_type": "matching"
#                 }
#             ]
#         },
#         {
#             "title_text": "A Steadfast Mind, a Peaceful Heart",
#             "description_text": "Amidst the chaos and uncertainty of the world, God offers us a haven of peace. Today's devotional explores how keeping our minds focused on Him can lead to a tranquility that surpasses all understanding.",
#             "content_text": "Isaiah 26:3 promises, \"You will keep in perfect peace all who trust in you, all whose thoughts are fixed on you.\"  This verse highlights the connection between our minds and our peace.  When our thoughts are consumed by anxieties, fear, and worries, our hearts are left unsettled. But when we intentionally turn our minds to God, fixating on His promises, His character, and His love, a deep and abiding peace settles within us.\n\nThis doesn't mean we become immune to the trials and tribulations of life. It simply means that we learn to navigate them with a calm and steady spirit.  We can choose to focus on the truth that God is in control, even when the world around us seems to be spiraling out of control. We can choose to trust His plans, even when they seem uncertain or painful. We can choose to find solace in His presence, even when our circumstances seem bleak.\n\nToday, take a moment to quiet your mind and bring your thoughts before God.  Let your anxieties fade as you meditate on His Word, His promises, and His love.  Trust that He is working all things together for good, and find peace in knowing that He is with you, guiding you through every storm.",
#             "id_study_content": "LHmbPFZEgLPbOys3w1Zr",
#             "activities": [
#                 {
#                     "question_text": "Even when things are tough, trusting God means we won't ever feel scared or worried again.",
#                     "answer_bool": false,
#                     "id_activity": "wdtVzweWfJcw4NkGx5jJ",
#                     "question_type": "true_or_false"
#                 },
#                 {
#                     "question_text": "What word in this verse describes the feeling we have when we trust God completely?  \"You will keep in perfect peace all who trust in you, all whose thoughts are fixed on you.\"  (Isaiah 26:3)",
#                     "unordered_word_text": "acep",
#                     "ordered_word_text": "peace",
#                     "id_activity": "u0QPtWhUi3vOPTmo3MbC",
#                     "question_type": "word_order"
#                 }
#             ]
#         },
#         {
#             "title_text": "The Anchor of Our Soul",
#             "description_text": "In the midst of chaos and uncertainty, God's peace offers an anchor for our souls. Today's devotional explores how God's peace guards our hearts and minds in the face of overwhelming circumstances.",
#             "content_text": "The world can feel like a tumultuous sea, tossed about by storms of conflict and uncertainty.  We may find ourselves caught in the waves of fear, anxiety, and worry. But amidst the chaos, God offers us a haven of peace \u2013 a steadfast anchor for our souls.\n\nPhilippians 4:6-7 encourages us not to be anxious, but to bring our requests to God. His peace, which transcends understanding, will guard our hearts and minds.  This peace isn't a mere feeling of calmness; it's a deep, abiding trust in God's sovereignty and His love for us.\n\nJust as a ship's anchor keeps it from being swept away by the waves, God's peace grounds us in the midst of life's storms. It gives us a sense of security and stability, knowing that even when the world around us is in upheaval, He remains constant and unchanging.\n\nToday, take time to meditate on these verses.  Reflect on how God's peace can be your anchor in the midst of chaos.  Bring your anxieties and worries to Him, trusting that He will provide the peace you need to navigate through life's storms.",
#             "id_study_content": "CfoiIe34J32pIpk8jZZH",
#             "activities": [
#                 {
#                     "question_text": "Can you rearrange these words to make a sentence about how God helps us during hard times? ",
#                     "unordered_sentence_text": "God's  peace  a  like  anchor  is  storm  in  a  during ",
#                     "ordered_sentence_text": "God's peace is like an anchor during a storm",
#                     "id_activity": "3LzPBu3zLglMioUL3ghQ",
#                     "question_type": "sentence_order"
#                 },
#                 {
#                     "question_text": "God's peace is like a ship's anchor, keeping us steady even when life gets stormy.",
#                     "answer_bool": true,
#                     "id_activity": "UW1FdmrxcOPXxoj7UFWo",
#                     "question_type": "true_or_false"
#                 }
#             ]
#         }
#     ]
# }

# %%
# module_generator.add_more_activities("T3IKWi3fZaNyA9Sl8tjA", 3)

# %%
# print(json.dumps(generated_content, indent=4))
# Out:
# {
#     "study_contents": [
#         {
#             "title_text": "Finding Peace in the Midst of Chaos",
#             "description_text": "When the world around us feels like it's crumbling, how can we find peace within?  This devotional explores how God's peace, a peace that surpasses understanding, can be our anchor in the storms of life.",
#             "content_text": "The world can be a chaotic place. News headlines are filled with conflict, economic uncertainty, and natural disasters. It's easy to feel overwhelmed, anxious, and even afraid. But amidst this chaos, God offers us a promise: His peace. Philippians 4:6-7 reminds us, \"Do not be anxious about anything, but in every situation, by prayer and petition, with thanksgiving, present your requests to God. And the peace of God, which transcends all understanding, will guard your hearts and your minds in Christ Jesus.\"  \n\nThis peace is not the absence of problems, but rather a deep sense of inner calm and security that comes from knowing that God is in control. It's a peace that surpasses human understanding because it's not based on our circumstances, but on our relationship with God. \n\nTo experience this peace, we need to actively seek it through prayer and communion with God. We need to trust that He is working in our lives, even when we can't see His hand. We need to bring our anxieties and fears to Him, believing that He will provide for us and guide us through whatever we face. \n\nToday, take some time to reflect on the chaos in your own life. What are you anxious about? What fears are weighing on your heart? Turn to God in prayer, acknowledging your need for His peace.  Ask Him to guard your heart and mind, and believe that He will.  Remember, His peace is available to you, even in the midst of the storm. ",
#             "id_study_content": "tdeiFptjleqSJxSCOG01",
#             "activities": [
#                 {
#                     "question_text": "What word describes the feeling God gives us that is more than just the absence of problems, but a deep sense of calm and security?",
#                     "unordered_word_text": "caeps",
#                     "ordered_word_text": "peace",
#                     "id_activity": "YWLJgFndtwYBZTX8rXPy",
#                     "question_type": "word_order"
#                 },
#                 {
#                     "question_text": "Think about a time when you felt really worried or scared. What did you do to try and feel better?",
#                     "hint_text": "Maybe you talked to someone you trust, or did something you enjoy. Think about what helps you feel calm.",
#                     "answer_text": "Answers will vary. Encourage kids to share their experiences and how they cope with fear or worry.  The goal is to help them understand that seeking support and finding things that bring comfort can help them feel calmer, just like the peace God offers.",
#                     "id_activity": "HXOP7P8BrmOsNr5lYpzk",
#                     "question_type": "open_ended_question"
#                 }
#             ]
#         },
#         {
#             "title_text": "The Steadfast Mind: A Foundation for Peace",
#             "description_text": "In a world filled with uncertainty and turmoil, finding peace can feel like an impossible task.  But God offers a promise of perfect peace to those with steadfast minds. This devotional delves into Isaiah 26:3 and explores how we can cultivate a steadfast spirit in the face of chaos.",
#             "content_text": "**Isaiah 26:3** says, \"You will keep in perfect peace him whose mind is steadfast, because he trusts in you.\" This verse speaks to the core of finding peace amidst chaos.  It's not about ignoring the storm raging around us, but rather about choosing to fix our minds on God, trusting in His unwavering presence.  \n\n**How can we cultivate a steadfast mind?**\n\n* **Dwell on God's Word:**  Regularly reading and meditating on Scripture helps us to know God's character, His promises, and His unwavering love.  This builds our confidence in Him and grounds us in His truth.\n* **Pray Continuously:**  Communicating with God through prayer keeps our focus on Him, even when our circumstances feel overwhelming.  It allows us to surrender our anxieties and find peace in His loving care.\n* **Practice Gratitude:**  Focusing on the blessings in our lives, even in the midst of difficulties, shifts our perspective.  Gratitude helps us see beyond the chaos and recognize God's faithfulness. \n\n**Reflection:**\n\nTake a moment to reflect on the areas of your life where you're feeling anxious or unsettled.  Ask God to help you cultivate a steadfast mind by focusing on His Word, seeking His guidance in prayer, and practicing gratitude for His blessings.  Trust that as you draw closer to Him, His peace will guard your heart and mind, even in the midst of chaos.",
#             "id_study_content": "T3IKWi3fZaNyA9Sl8tjA",
#             "activities": [
#                 {
#                     "question_text": "How can we learn to trust God and find peace even when things are tough?",
#                     "unordered_sentence_text": "God's in our on Him  we can by focusing  Word  peace find  ",
#                     "ordered_sentence_text": "We can find peace by focusing on God's Word and trusting in Him",
#                     "id_activity": "GeUKeZAasCcyRhqTpZa6",
#                     "question_type": "sentence_order"
#                 },
#                 {
#                     "question_text": "Reading the Bible every day helps us to know God's promises and love, which can make us feel calmer and more confident in Him.",
#                     "answer_bool": true,
#                     "id_activity": "Q2IeaT3pvkP6u7E9ECq1",
#                     "question_type": "true_or_false"
#                 },
#                 {
#                     "question_text": "Praying to God every day helps us focus on Him and feel less worried, even when things are hard.",
#                     "answer_bool": true,
#                     "id_activity": "6yYnTkGgHCofaY9jnWlR",
#                     "question_type": "true_or_false"
#                 },
#                 {
#                     "question_text": "Focusing on good things in our lives, even when things are hard, can help us feel more grateful and less worried.",
#                     "answer_bool": true,
#                     "id_activity": "zaOnFJNdyFn5f88ZvL9j",
#                     "question_type": "true_or_false"
#                 },
#                 {
#                     "question_text": "Imagine you're feeling really worried about something. How can you turn your thoughts to God and find peace in His love?",
#                     "hint_text": "Think about how reading the Bible and talking to God in prayer can help you feel closer to Him.",
#                     "answer_text": "We can turn our thoughts to God by reading His Word, the Bible, and talking to Him in prayer. This helps us focus on His love and promises, which can bring us peace and calm even when we're worried.",
#                     "id_activity": "QdOKGoMiOkM4vlc0qxKY",
#                     "question_type": "open_ended_question"
#                 }
#             ]
#         },
#         {
#             "title_text": "Praying for Peace: Bringing Our Requests to God",
#             "description_text": "In the face of overwhelming chaos, anxiety can easily grip our hearts. But God offers us a powerful promise: His peace that surpasses all understanding. This devotional explores Philippians 4:6-7 and how bringing our anxieties to God can open the door to His calming presence.",
#             "content_text": "**Question:** How can we experience God's peace even when surrounded by turmoil and uncertainty? \n\n**Answer:** Philippians 4:6-7 reminds us that we don't have to navigate the storms of life alone. The verse says, \"Do not be anxious about anything, but in every situation, by prayer and petition, with thanksgiving, present your requests to God. And the peace of God, which transcends all understanding, will guard your hearts and your minds in Christ Jesus.\" \n\nThis passage encourages us to bring our anxieties and concerns to God in prayer. When we do, He promises to fill us with His peace, a peace that is deeper and more profound than anything we could imagine. This peace doesn't mean that we will never experience hardship or challenges, but it does mean that we can face them with a sense of calm and trust, knowing that God is with us. \n\n**Reflection:**  Take a moment to reflect on the areas in your life that are causing you anxiety.  Write down your concerns and then bring them before God in prayer, asking for His peace to guide you and His strength to sustain you. Trust that He will provide the peace you need, even in the midst of chaos.",
#             "id_study_content": "npTgHu1Ns0vx8Xz8epJG",
#             "activities": [
#                 {
#                     "question_text": "What does Philippians 4:6-7 say we should do when we're feeling worried?",
#                     "answer_text": "Pray to God about our worries and ask for His peace.",
#                     "options_list": [
#                         "Ignore our worries and pretend they don't exist.",
#                         "Try to solve our problems on our own.",
#                         "Talk to our friends about our problems.",
#                         "Get angry about our worries."
#                     ],
#                     "id_activity": "oUCNXCDhWxdIVzxKZ5iY",
#                     "question_type": "multiple_choice"
#                 },
#                 {
#                     "question_text": "What does Philippians 4:6-7 tell us to do when we're feeling anxious?",
#                     "answer_text": "Pray to God and ask for His peace.",
#                     "options_list": [
#                         "Ignore our worries and pretend they don't exist.",
#                         "Try to solve everything ourselves.",
#                         "Blame others for our problems.",
#                         "Give up and stop trying.",
#                         "Keep our worries to ourselves"
#                     ],
#                     "id_activity": "fcRpY9qZI0G3jkxonePR",
#                     "question_type": "multiple_choice"
#                 }
#             ]
#         }
#     ]
# }

# %%
generated_content = module_generator.regenerate_content("LHmbPFZEgLPbOys3w1Zr", 2, "Relate this devotional with star wars.")

# %%
print(json.dumps(generated_content, indent=4))
# Out:
# {
#     "study_contents": [
#         {
#             "title_text": "Finding Peace in a World of Conflict",
#             "description_text": "In the midst of turmoil and uncertainty, the promise of God's peace remains steadfast. Today's devotional explores how we can find that peace amidst the chaos.",
#             "content_text": "The world can feel like a chaotic and unpredictable place, especially when we are surrounded by conflict and unrest. The news is often filled with stories of war, violence, and suffering, and it can be easy to feel overwhelmed and anxious. But even in the midst of this turmoil, God promises us His peace.  \n\nPhilippians 4:6-7 reminds us, \"Do not be anxious about anything, but in every situation, by prayer and petition, with thanksgiving, present your requests to God. And the peace of God, which transcends all understanding, will guard your hearts and your minds in Christ Jesus.\" \n\nThis peace is not simply the absence of trouble; it is a deep, abiding peace that comes from knowing that God is in control. It is a peace that surpasses our understanding, a peace that is present even in the midst of storm.  \n\nHow can we find this peace? The passage tells us to bring our requests to God in prayer. When we acknowledge our fears and anxieties and surrender them to God, we open ourselves up to His peace. We also find peace by focusing on gratitude. When we focus on the good things in our lives, even in the midst of difficult circumstances, we cultivate a sense of peace and contentment.\n\nRemember, you are not alone. God is with you, and His peace is available to you, no matter what you are facing. Take time today to seek His peace through prayer, gratitude, and trusting in His goodness.",
#             "id_study_content": "mBZ1hWMsEsG9nNGI7swy",
#             "activities": [
#                 {
#                     "question_text": "How can focusing on the good things in life, even when things are tough, help us find peace?",
#                     "hint_text": "Think about times when something good happened even though you were going through a difficult time. How did that make you feel?",
#                     "answer_text": "Focusing on the good things reminds us that God is still working in our lives, even when we don't see it. It helps us to be grateful for what we have, which can bring us peace and contentment, even in the midst of challenges.",
#                     "id_activity": "8z6HuWm5RuJ51sLB4MVM",
#                     "question_type": "open_ended_question"
#                 },
#                 {
#                     "question_text": "What does the Bible say we can do to find peace even when the world feels chaotic?",
#                     "list_options": [
#                         "Sing loud songs",
#                         "Pray to God and tell Him our worries",
#                         "Read a book",
#                         "Take a nap",
#                         "Watch TV"
#                     ],
#                     "list_matches": [
#                         "Incorrect",
#                         "Correct",
#                         "Incorrect",
#                         "Incorrect",
#                         "Incorrect"
#                     ],
#                     "id_activity": "8eYOEr7SZx6L5TGlHvoF",
#                     "question_type": "matching"
#                 }
#             ]
#         },
#         {
#             "title_text": "Finding Peace in the Force",
#             "description_text": "In the midst of galactic battles and chaotic political landscapes, the Jedi Knights remind us that true peace comes from within. Today's devotional explores the connection between a steady mind and finding peace in the midst of chaos, drawing inspiration from the Star Wars galaxy.",
#             "content_text": "Imagine the Jedi Knights facing down the might of the Empire, wielding lightsabers in epic battles across the galaxy. Their training emphasized not just physical prowess, but also the mastery of their minds. Through intense meditation, they learned to focus their thoughts, achieving inner peace and tranquility even in the face of danger.  They understood that their strength came not from weapons, but from the Force, an energy field that connected all living beings. This unwavering faith in the Force allowed them to navigate even the most perilous situations with a calm and steady spirit.\n\nThe Jedi Knights, much like the believers in scripture, learned to trust in something beyond themselves. Their faith in the Force, much like our faith in God, gave them the courage and strength to persevere through the darkest of times. Just as the Force connects all living beings, God's love connects us to Him and to each other. And through this connection, we find a peace that transcends our circumstances.\n\nThe Jedi Knights remind us that the battles we face in life are not just physical but spiritual.  We must fight the temptation to succumb to fear and anxiety, choosing instead to cultivate inner peace by focusing our minds on God's love and promises. Just as the Force flows through us, so does God's grace. Let us strive to be peacemakers in our own lives and in the world around us, drawing strength from the promise of God's peace.",
#             "id_study_content": "LHmbPFZEgLPbOys3w1Zr",
#             "activities": [
#                 {
#                     "question_text": "Imagine you are a Jedi Knight facing a scary situation. How can focusing on God's love and promises help you stay calm and brave?",
#                     "hint_text": "Think about what God promises us in the Bible. How can those promises make you feel stronger?",
#                     "answer_text": "Focusing on God's love and promises can remind us that we're not alone, even when things are scary. It can give us hope and courage to face anything, just like the Jedi Knights trusted in the Force.",
#                     "id_activity": "wQcjLzWg4dfjVyVTnKKR",
#                     "question_type": "open_ended_question"
#                 },
#                 {
#                     "question_text": "What word describes the feeling of calm and peace that comes from trusting in God?",
#                     "unordered_word_text": "aecp",
#                     "ordered_word_text": "peace",
#                     "id_activity": "qZ0tZciXbuhVku4tMcBD",
#                     "question_type": "word_order"
#                 }
#             ]
#         },
#         {
#             "title_text": "The Anchor of Our Soul",
#             "description_text": "In the midst of chaos and uncertainty, God's peace offers an anchor for our souls. Today's devotional explores how God's peace guards our hearts and minds in the face of overwhelming circumstances.",
#             "content_text": "The world can feel like a tumultuous sea, tossed about by storms of conflict and uncertainty.  We may find ourselves caught in the waves of fear, anxiety, and worry. But amidst the chaos, God offers us a haven of peace \u2013 a steadfast anchor for our souls.\n\nPhilippians 4:6-7 encourages us not to be anxious, but to bring our requests to God. His peace, which transcends understanding, will guard our hearts and minds.  This peace isn't a mere feeling of calmness; it's a deep, abiding trust in God's sovereignty and His love for us.\n\nJust as a ship's anchor keeps it from being swept away by the waves, God's peace grounds us in the midst of life's storms. It gives us a sense of security and stability, knowing that even when the world around us is in upheaval, He remains constant and unchanging.\n\nToday, take time to meditate on these verses.  Reflect on how God's peace can be your anchor in the midst of chaos.  Bring your anxieties and worries to Him, trusting that He will provide the peace you need to navigate through life's storms.",
#             "id_study_content": "CfoiIe34J32pIpk8jZZH",
#             "activities": [
#                 {
#                     "question_text": "Can you rearrange these words to make a sentence about how God helps us during hard times? ",
#                     "unordered_sentence_text": "God's  peace  a  like  anchor  is  storm  in  a  during ",
#                     "ordered_sentence_text": "God's peace is like an anchor during a storm",
#                     "id_activity": "3LzPBu3zLglMioUL3ghQ",
#                     "question_type": "sentence_order"
#                 },
#                 {
#                     "question_text": "God's peace is like a ship's anchor, keeping us steady even when life gets stormy.",
#                     "answer_bool": true,
#                     "id_activity": "UW1FdmrxcOPXxoj7UFWo",
#                     "question_type": "true_or_false"
#                 }
#             ]
#         }
#     ]
# }

# %%
generated_content = module_generator.regenerate_activity("dIRQwg77N0alpgTnhJzQ", "true_or_false")

# %%
print(json.dumps(generated_content, indent=4))
# Out:
# {
#     "study_contents": [
#         {
#             "title_text": "Finding Peace in a World of Chaos",
#             "description_text": "Amidst the turmoil that surrounds us, how can we cultivate inner peace? Explore the power of God's peace to guard our hearts and minds.",
#             "content_text": "The world is often a chaotic place, filled with conflict and uncertainty. War, injustice, and personal struggles can leave us feeling anxious and overwhelmed. Yet, even in the midst of such turmoil, Scripture reminds us of a truth that can bring us solace and strength: the peace of God. Philippians 4:6-7 encourages us to not be anxious but to bring our requests to God, trusting that His peace, which surpasses all understanding, will guard our hearts and minds. \n\nThis peace isn't simply the absence of stress or conflict. It's a deep and abiding sense of calm, security, and hope that comes from knowing God is with us, working all things for our good. It's the peace that Isaiah 26:3 promises to those whose minds are steadfast: 'You keep him in perfect peace whose mind is steadfast, because he trusts in you.' \n\nToday, take time to reflect on this truth. Meditate on Philippians 4:6-7 and Isaiah 26:3. Ask God to fill you with His peace, even in the midst of chaos. Remember that He is in control, and He is working for your good.  As you surrender your anxieties to Him, you will experience His peace in a way that transcends human understanding.",
#             "id_study_content": "CqOFRVyT5nNZACKxA9uv",
#             "activities": [
#                 {
#                     "question_text": "Even when the world is filled with ____ and ____, God's peace can bring us ____ and _____.",
#                     "list_blank_values": [
#                         "trouble",
#                         "problems",
#                         "comfort",
#                         "strength"
#                     ],
#                     "id_activity": "sWO3gG7B5ep77ixHvis3"
#                 },
#                 {
#                     "question_text": "When we feel ____ and ____, God's peace can help us feel ____ and _____.",
#                     "list_blank_values": [
#                         "anxious",
#                         "overwhelmed",
#                         "calm",
#                         "safe"
#                     ],
#                     "id_activity": "IjLyBBb6SHuLBqBlq5Y3"
#                 }
#             ]
#         },
#         {
#             "title_text": "The Steadfast Mind: A Foundation for Peace",
#             "description_text": "How can we find perfect peace amidst the chaos of our world? Discover the power of a steadfast mind, rooted in God's promises.",
#             "content_text": "Isaiah 26:3 speaks of a profound truth: \"You will keep in perfect peace those whose minds are steadfast, because they trust in you.\" This verse highlights the connection between peace and a steadfast mind. In a world of uncertainty and upheaval, our minds can easily be pulled in multiple directions, leading to anxiety and fear.  \n\nBut God invites us to find refuge in His unwavering presence. By choosing to trust in Him, to fix our minds on His promises, we create a foundation for inner peace that transcends the chaos around us. \n\nToday, take time to reflect on these truths: \n\n* **What are the sources of anxiety and unrest in your life?**\n* **How can you choose to fix your mind on God's promises instead of the world's worries?**\n* **What specific scriptures offer you comfort and hope?**\n\nLet the peace of God, which surpasses all understanding, guard your heart and mind in Christ Jesus (Philippians 4:7).",
#             "id_study_content": "258suBTey5rlfpmXilCv",
#             "activities": [
#                 {
#                     "question_text": "What does Isaiah 26:3 tell us helps us find peace in a world that's always changing?",
#                     "answer_text": "Trusting in God",
#                     "options_list": [
#                         "Having lots of friends",
#                         "Being really good at sports",
#                         "Having lots of money",
#                         "Getting good grades in school",
#                         "Being really funny"
#                     ],
#                     "id_activity": "U1L38SQGamwwIr0Z9bHJ"
#                 },
#                 {
#                     "question_text": "When we worry about things, it's like we are trusting in God's promises instead of the world's worries.",
#                     "answer_bool": false,
#                     "id_activity": "dIRQwg77N0alpgTnhJzQ"
#                 }
#             ]
#         },
#         {
#             "title_text": "Praying for Peace in the Storm",
#             "description_text": "How can we access God's peace when the world feels like it's falling apart?  Let's explore how prayer can bring us peace that surpasses understanding.",
#             "content_text": "The world often feels chaotic, doesn't it?  News headlines are filled with conflict, and even our personal lives can be turbulent.  But in the midst of this storm, God promises us peace. Philippians 4:6-7 reminds us not to be anxious, but to bring our requests to God in prayer. He promises that His peace, which transcends understanding, will guard our hearts and minds.  \n\nToday, let's take time to pray for peace.  Pray for peace in the world, for peace in our own lives, and for peace in the hearts of those who are suffering.  We can ask God to bring comfort and hope to those who are hurting, and to guide us toward actions that promote peace and understanding.  As we pray, let us remember that God is always with us, and His peace is always available to us.  \n\n**Reflect:** What are some things you are anxious about today? How can you bring these concerns to God in prayer? How can you use your own life to promote peace and understanding in the world around you?",
#             "id_study_content": "5XEYDGKAOoruNEDkp77M",
#             "activities": [
#                 {
#                     "question_text": "Philippians 4:6-7 reminds us not to be _____, but to bring our requests to God in _____.",
#                     "list_blank_values": [
#                         "anxious",
#                         "prayer"
#                     ],
#                     "id_activity": "Sr2AQgiVqhFUKrE4nW5s"
#                 },
#                 {
#                     "question_text": "What is one thing you can do to bring peace to others?",
#                     "answer_text": "Be kind and helpful to people.",
#                     "options_list": [
#                         "Watch TV.",
#                         "Argue with people who are different.",
#                         "Tell people what to do.",
#                         "Ignore people who are struggling.",
#                         "Do whatever you want."
#                     ],
#                     "id_activity": "unAOq7Ij3XFEO5Pmz1rK"
#                 }
#             ]
#         }
#     ]
# }
